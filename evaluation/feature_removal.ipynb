# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("df_regression.csv")
data.columns
# Out:
# Index(['Unnamed: 0', 'Model Name', 'Dataset', 'Subset ID', 'Is Filtered',
#        'Sensitive Feature', 'ndcg@5', 'recall@5', 'mrr@5',
#        'Differential Fairness of sensitive attribute', 'giniindex@5',
#        'popularitypercentage@5', 'Value Unfairness of sensitive attribute',
#        'Absolute Unfairness of sensitive attribute',
#        'Underestimation Unfairness of sensitive attribute',
#        'Overestimation Unfairness of sensitive attribute',
#        'NonParity Unfairness of sensitive attribute', 'Absolute Difference',
#        'KS Statistic of sensitive attribute', 'Generalized Cross Entropy',
#        'hit@5', 'Number of Users', 'Number of Items', 'Number of Ratings',
#        'Space Size', 'Shape', 'Density', 'Rating per User', 'Rating per Item',
#        'Gini Item', 'Gini User', 'Average Popularity',
#        'Standart Deviation of Popularity Bias', 'Skewness of Popularity Bias',
#        'Kurtosis of Popularity Bias', 'Average Long Tail Items',
#        'Standart Deviation of Long Tail Items', 'Skewness of Long Tail Items',
#        'Kurtosis of Long Tail Items', 'Mean Rating',
#        'Standart Deviation of Rating', 'Skewness of Rating',
#        'Kurtosis of Rating', 'Sensitive Attribute == 0 Percentage',
#        'Sensitive Attribute == 1 Percentage',
#        'Difference between Sensitive Attribute Percentage'],
#       dtype='object')

# %%
data_age = pd.read_csv("../stats/stats_ml1m_age.csv")
data_age["Sensitive Feature"] = "age"
data_gender = pd.read_csv("../stats/stats_ml1m_gender.csv")
data_gender["Sensitive Feature"] = "gender"
data_bx = pd.read_csv("../stats/stats_bx_age.csv")
data_bx["Sensitive Feature"] = "age"
data = pd.concat([data_age, data_gender, data_bx])
data
# Out:
#    Dataset  Subset ID Is Filtered  Number of Users  Number of Items  \
# 0     ml1m          1         Yes              273             1122
# 1     ml1m          2         Yes             1622             1196
# 2     ml1m          3         Yes              961              766
# 3     ml1m          4         Yes              753             1493
# 4     ml1m          5         Yes              167             1341
# ..     ...        ...         ...              ...              ...
# 95      BX         96         Yes             1450             3057
# 96      BX         97         Yes              215             1485
# 97      BX         98         Yes             4607             3081
# 98      BX         99         Yes             1057             3450
# 99      BX        100         Yes             2875             4135
#
#     Number of Ratings  Space Size  Shape  Density  Rating per User  ...  \
# 0               11957      306306  0.243    0.039           43.799  ...
# 1               66286     1939912  1.356    0.034           40.867  ...
# 2               23594      736126  1.255    0.032           24.552  ...
# 3               39148     1124229  0.504    0.035           51.989  ...
# 4                9504      223947  0.125    0.042           56.910  ...
# ..                ...         ...    ...      ...              ...  ...
# 95              18537     4432650  0.474    0.004           12.784  ...
# 96               2769      319275  0.145    0.009           12.879  ...
# 97              57278    14194167  1.495    0.004           12.433  ...
# 98              15808     3646650  0.306    0.004           14.956  ...
# 99              48463    11888125  0.695    0.004           16.857  ...
#
#     Skewness of Long Tail Items  Kurtosis of Long Tail Items  Mean Rating  \
# 0                         1.674                        2.563        3.492
# 1                         2.056                        6.095        3.601
# 2                         2.119                        5.937        3.548
# 3                         2.441                        9.134        3.565
# 4                         2.977                       11.419        3.607
# ..                          ...                          ...          ...
# 95                        1.697                        3.262        1.983
# 96                        1.726                        2.957        1.861
# 97                        1.646                        3.079        2.030
# 98                        1.832                        4.304        1.979
# 99                        1.748                        3.939        1.991
#
#     Standart Deviation of Rating  Skewness of Rating  Kurtosis of Rating  \
# 0                          1.172              -0.521              -0.467
# 1                          1.123              -0.583              -0.323
# 2                          1.133              -0.530              -0.417
# 3                          1.131              -0.542              -0.404
# 4                          1.104              -0.545              -0.349
# ..                           ...                 ...                 ...
# 95                         1.523               1.046              -0.664
# 96                         1.488               1.266              -0.191
# 97                         1.547               0.975              -0.817
# 98                         1.527               1.055              -0.655
# 99                         1.530               1.037              -0.687
#
#     Sensitive Attribute == 0 Percentage  Sensitive Attribute == 1 Percentage  \
# 0                                 23.81                                76.19
# 1                                 19.79                                80.21
# 2                                 23.00                                77.00
# 3                                 22.97                                77.03
# 4                                 26.35                                73.65
# ..                                  ...                                  ...
# 95                                39.66                                60.34
# 96                                40.93                                59.07
# 97                                39.53                                60.47
# 98                                39.92                                60.08
# 99                                39.10                                60.90
#
#     Difference between Sensitive Attribute Percentage  Sensitive Feature
# 0                                               52.38                age
# 1                                               60.42                age
# 2                                               54.00                age
# 3                                               54.06                age
# 4                                               47.30                age
# ..                                                ...                ...
# 95                                              20.68                age
# 96                                              18.14                age
# 97                                              20.94                age
# 98                                              20.16                age
# 99                                              21.80                age
#
# [300 rows x 29 columns]

# %%
ml1_age = data[(data["Dataset"] == "ml1m") & (data["Sensitive Feature"] == "Age")]

# %%
ml1_gender = data[(data["Dataset"] == "ml1m") & (data["Sensitive Feature"] == "Gender")]

# %%
bx_age = data[(data["Dataset"] == "BX") & (data["Sensitive Feature"] == "Age")]

# %%
data = data.iloc[:, 3:-1]
data.drop(columns=["Sensitive Attribute == 0 Percentage", "Sensitive Attribute == 1 Percentage"], axis=1, inplace=True)
corr = data.corr(method="spearman")
corr['Difference between Sensitive Attribute Percentage'].drop('Difference between Sensitive Attribute Percentage').abs().sort_values(ascending=False)
# Out:
# Standart Deviation of Popularity Bias    0.691656
# Average Popularity                       0.686938
# Density                                  0.684394
# Standart Deviation of Rating             0.676018
# Gini Item                                0.675621
# Skewness of Rating                       0.675054
# Gini User                                0.673373
# Mean Rating                              0.669476
# Number of Items                          0.666574
# Skewness of Popularity Bias              0.653742
# Kurtosis of Popularity Bias              0.647094
# Kurtosis of Rating                       0.624763
# Space Size                               0.561815
# Skewness of Long Tail Items              0.551425
# Rating per Item                          0.508705
# Average Long Tail Items                  0.487319
# Rating per User                          0.484147
# Kurtosis of Long Tail Items              0.453183
# Number of Users                          0.424474
# Standart Deviation of Long Tail Items    0.306887
# Shape                                    0.176610
# Number of Ratings                        0.153893
# Name: Difference between Sensitive Attribute Percentage, dtype: float64

# %%
bx_age = bx_age.iloc[:, 3:-4]
ml1_age = ml1_age.iloc[:, 3:-4]
ml1_gender = ml1_gender.iloc[:, 3:-4]
data = data.iloc[:, 3:-4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 5
#       3 ml1_gender = ml1_gender.iloc[:, 3:-4]
#       4 data = data.iloc[:, 3:-4]
# ----> 5 data.drop(columns=["Sensitive Attribute == 0 Percentage", "Sensitive Attribute == 1 Percentage"], axis=1, inplace=True)
#
# File ~/PycharmProjects/RecBole-FairRec-Comparison-Tool/venv/lib/python3.8/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~/PycharmProjects/RecBole-FairRec-Comparison-Tool/venv/lib/python3.8/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/PycharmProjects/RecBole-FairRec-Comparison-Tool/venv/lib/python3.8/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/PycharmProjects/RecBole-FairRec-Comparison-Tool/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['Sensitive Attribute == 0 Percentage', 'Sensitive Attribute == 1 Percentage'] not found in axis"

# %%
#Calculate correlation matrix for each data
corr_ml1_age = ml1_age.corr()
corr_ml1_gender = ml1_gender.corr()
corr_bx_age = bx_age.corr()
corr_data = data.corr(method='spearman')

# %%
#Plot correlation matrix
plt.figure(figsize=(16, 14))
sns.heatmap(corr,annot=True,fmt=".2f", cmap='coolwarm')
# Out:
# <Axes: >

# %%
#Set threshold as 0.8 drop one of the pairs of highly correlated features
threshold = 0.65
corr_matrix2 = data.corr(method='spearman').abs()

# Find highly correlated pairs
upper_triangle2 = corr_matrix2.where(np.triu(np.ones(corr_matrix2.shape), k=1).astype(bool))

# Find column pairs where correlation > threshold
highly_correlated2 = [column for column in upper_triangle2.columns if any(upper_triangle2[column] > threshold)]

# Drop one of each pair (keep the first occurrence)
df_reduced2 = corr_matrix2.drop(columns=highly_correlated2)

print(f"Columns to drop: {len(highly_correlated2)}")
print(highly_correlated2)
print(f"Remaining columns: {df_reduced.shape[1]}")
df_reduced.columns
# Out:
# Columns to drop: 18
# ['Number of Ratings', 'Space Size', 'Rating per User', 'Rating per Item', 'Gini Item', 'Gini User', 'Average Popularity', 'Standart Deviation of Popularity Bias', 'Skewness of Popularity Bias', 'Kurtosis of Popularity Bias', 'Average Long Tail Items', 'Standart Deviation of Long Tail Items', 'Skewness of Long Tail Items', 'Kurtosis of Long Tail Items', 'Mean Rating', 'Standart Deviation of Rating', 'Skewness of Rating', 'Kurtosis of Rating']
# Remaining columns: 7
# Index(['Number of Users', 'Number of Items', 'Shape', 'Density', 'Gini User',
#        'Skewness of Popularity Bias', 'Standart Deviation of Rating'],
#       dtype='object')

# %%
threshold = 0.7

# Find highly correlated pairs
upper_triangle = corr_data.where(np.triu(np.ones(corr_data.shape), k=1).astype(bool))

# Find column pairs where correlation > threshold
highly_correlated = [column for column in upper_triangle.columns if any(upper_triangle[column] > threshold)]

# Drop one of each pair (keep the first occurrence)
df_reduced = corr_data.drop(columns=highly_correlated)

# Print results
print(f"Columns to drop: {len(highly_correlated)}")
print(highly_correlated)
# Out:
# Columns to drop: 15
# ['Number of Ratings', 'Space Size', 'Rating per User', 'Rating per Item', 'Gini Item', 'Average Popularity', 'Standart Deviation of Popularity Bias', 'Kurtosis of Popularity Bias', 'Average Long Tail Items', 'Standart Deviation of Long Tail Items', 'Skewness of Long Tail Items', 'Kurtosis of Long Tail Items', 'Mean Rating', 'Skewness of Rating', 'Kurtosis of Rating']

# %%
set(data.columns) - set(highly_correlated)
# Out:
# {'Density',
#  'Gini User',
#  'Number of Items',
#  'Number of Users',
#  'Shape',
#  'Skewness of Popularity Bias',
#  'Standart Deviation of Rating'}

# %%
def drop_features(data,threshold):
    corr_matrix = data.corr().abs()
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool_))
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
    return data.drop(data[to_drop], axis=1)

ml1_age_dropped_8 = drop_features(ml1_age.copy(), 0.8)
ml1_gender_dropped_8 = drop_features(ml1_gender.copy(), 0.8)
bx_age_dropped_8 = drop_features(bx_age.copy(), 0.8)
data_8 = drop_features(data.copy(), 0.8)

ml1_age_dropped_7 = drop_features(ml1_age.copy(), 0.7)
ml1_gender_dropped_7 = drop_features(ml1_gender.copy(), 0.7)
bx_age_dropped_7 = drop_features(bx_age.copy(), 0.7)
data_7 = drop_features(data.copy(), 0.7)

ml1_age_dropped_6 = drop_features(ml1_age.copy(), 0.6)
ml1_gender_dropped_6 = drop_features(ml1_gender.copy(), 0.6)
bx_age_dropped_6 = drop_features(bx_age.copy(), 0.6)
data_6 = drop_features(data.copy(), 0.6)

# %%
len(dropped_features_data_8)
# Out:
# 15

# %%
#Find the dropped features
dropped_features_ml1_age_8 = [col for col in ml1_age.columns if col not in ml1_age_dropped_8.columns]
dropped_features_ml1_gender_8 = [col for col in ml1_gender.columns if col not in ml1_gender_dropped_8.columns]
dropped_features_bx_age_8 = [col for col in bx_age.columns if col not in bx_age_dropped_8.columns]
dropped_features_data_8 = [col for col in data.columns if col not in data_8.columns]

dropped_features_ml1_age_7 = [col for col in ml1_age.columns if col not in ml1_age_dropped_7.columns]
dropped_features_ml1_gender_7 = [col for col in ml1_gender.columns if col not in ml1_gender_dropped_7.columns]
dropped_features_bx_age_7 = [col for col in bx_age.columns if col not in bx_age_dropped_7.columns]
dropped_features_data_7 = [col for col in data.columns if col not in data_7.columns]

drop_features_ml1_age_6 = [col for col in ml1_age.columns if col not in ml1_age_dropped_6.columns]
dropped_features_ml1_gender_6 = [col for col in ml1_gender.columns if col not in ml1_gender_dropped_6.columns]
dropped_features_bx_age_6 = [col for col in bx_age.columns if col not in bx_age_dropped_6.columns]
dropped_features_data_6 = [col for col in data.columns if col not in data_6.columns]

# %%
dropped_features_bx_age_8, dropped_features_ml1_gender_8,dropped_features_data_8
# Out:
# (['Number of Ratings',
#   'Space Size',
#   'Shape',
#   'Rating per User',
#   'Rating per Item',
#   'Gini Item',
#   'Kurtosis of Popularity Bias',
#   'Average Long Tail Items',
#   'Standart Deviation of Long Tail Items',
#   'Kurtosis of Long Tail Items',
#   'Standart Deviation of Rating',
#   'Skewness of Rating',
#   'Kurtosis of Rating'],
#  ['Space Size',
#   'Rating per User',
#   'Rating per Item',
#   'Kurtosis of Popularity Bias',
#   'Average Long Tail Items',
#   'Standart Deviation of Long Tail Items',
#   'Kurtosis of Long Tail Items',
#   'Skewness of Rating'],
#  ['Space Size',
#   'Density',
#   'Gini Item',
#   'Gini User',
#   'Average Popularity',
#   'Standart Deviation of Popularity Bias',
#   'Skewness of Popularity Bias',
#   'Kurtosis of Popularity Bias',
#   'Average Long Tail Items',
#   'Standart Deviation of Long Tail Items',
#   'Kurtosis of Long Tail Items',
#   'Mean Rating',
#   'Standart Deviation of Rating',
#   'Skewness of Rating',
#   'Kurtosis of Rating'])

# %%
#Correlation matrix after dropping features
corr_ml1_age_after_8 = ml1_age_dropped_8.corr()
plt.figure(figsize=(16, 14))
sns.heatmap(corr_ml1_age_after_8,annot=True,fmt=".2f", cmap='coolwarm')
# Out:
# <Axes: >

# %%
bx_age_dropped_8 = bx_age_dropped_8.corr()
plt.figure(figsize=(16, 14))
sns.heatmap(bx_age_dropped_8,annot=True,fmt=".2f", cmap='coolwarm')
# Out:
# <Axes: >

# %%
data_8 = data_8.corr()
plt.figure(figsize=(16, 14))
-sns.heatmap(data_8,annot=True,fmt=".2f", cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 data_8 = data_8.corr()
#       2 plt.figure(figsize=(16, 14))
# ----> 3 -sns.heatmap(data_8,annot=True,fmt=".2f", cmap='coolwarm')
#
# TypeError: bad operand type for unary -: 'Axes'

# %%
ml1_age_dropped_7 = ml1_age_dropped_7.corr()
plt.figure(figsize=(16, 14))
sns.heatmap(ml1_age_dropped_7,annot=True,fmt=".2f", cmap='coolwarm')

# %%
bx_age_dropped_7 = bx_age_dropped_7.corr()
plt.figure(figsize=(16, 14))
sns.heatmap(bx_age_dropped_7,annot=True,fmt=".2f", cmap='coolwarm')
# Out:
# <Axes: >

# %%
data_7 = data_7.corr()
plt.figure(figsize=(16, 14))
sns.heatmap(data_7,annot=True,fmt=".2f", cmap='coolwarm')
# Out:
# <Axes: >

# %%
ml1_age_dropped_6 = ml1_age_dropped_6.corr()
plt.figure(figsize=(16, 14))
sns.heatmap(ml1_age_dropped_6,annot=True,fmt=".2f", cmap='coolwarm')
# Out:
# <Axes: >

# %%
bx_age_dropped_6 = bx_age_dropped_6.corr()
plt.figure(figsize=(16, 14))
sns.heatmap(bx_age_dropped_6,annot=True,fmt=".2f", cmap='coolwarm')
# Out:
# <Axes: >

# %%
data_6 = data_6.corr()
plt.figure(figsize=(16, 14))
sns.heatmap(data_6,annot=True,fmt=".2f", cmap='coolwarm')
# Out:
# <Axes: >
